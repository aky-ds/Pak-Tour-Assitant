# %%
from tavily import TavilyClient
import os
from dotenv import load_dotenv

load_dotenv()

client = TavilyClient(
    api_key=os.getenv("TAVILY_API_KEY")
)

####################################



def tavily_search(query):
    response = client.search(
        query=query,
        max_results=5
    )
    print(response)

    results = []

    for i, r in enumerate(response["results"], 1):
        title   = r.get("title", "Unknown")
        url     = r.get("url", "")
        snippet = r.get("content", "").strip()
        # Keep only the first 300 characters to avoid wall-of-text
        if len(snippet) > 300:
            snippet = snippet[:300].rsplit(" ", 1)[0] + "..."

        results.append(f"{i}. **{title}**\n   {url}\n   {snippet}")

    return "\n\n".join(results)
    
    
tavily_search("Tell me about the best tourism Places in Karachi")
# Out:
# {'query': 'Tell me about the best tourism Places in Karachi', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.natureadventureclub.pk/best-tourist-attractions-in-karachi', 'title': 'Famous Tourist Attractions in Karachi 2026 Places to Visit', 'content': '# Best Things to do in Visit Karachi with Family 2026. Pakistan Tour Packages > Best Things to do in Visit Karachi with Family 2026. Tourist attractions in Karachi with Family. Port Grand is a perfect tourist attraction for a nighttime outing in Karachi. Featuring a charming promenade, a variety of eateries, shops, and fun activities, it is a **must-visit location**. Situated on a beautifully recreated old pier, it offers a unique experience that is easily accessible via Maulvi Tamizuddin Road, with valet parking available for a fee. An entrance fee is required, but it is discounted with any purchase at the outlets or eateries. The promenade is **perfect for couples and families** alike, with plenty of seating to enjoy the refreshing sea breeze after a hot day in Karachi. Dolmen Mall Karachi offers a vibrant and comprehensive shopping experience that caters to a variety of tastes and needs. With enhancements in cleanliness and crowd control, it’s one of the best places to visit in Karachi.', 'score': 0.99998164, 'raw_content': None}, {'url': 'https://sg.trip.com/travel-guide/attraction/karachi-21342/tourist-attractions', 'title': '10 Top Attractions in Karachi (2026) | Trip.com', 'content': '1. Port Grand - Karachi · 2. Pakistan Air Force Museum · 3. Pakistan Maritime Museum · 4. Expo Centre Karachi · 5. Mazaar e Quaid Muhammad Ali Jinnah Mausoleum · 6.', 'score': 0.9998287, 'raw_content': None}, {'url': 'https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Karachi', 'title': 'List of tourist attractions in Karachi - Wikipedia', 'content': 'Monuments, mosques, temples and memorials · Hindu Gymkhana · Jehangir Kothari Parade · Grand Jamia Mosque · Masjid-e-Tooba · Mazare-e-Quaid Tomb · Shree Ratneshwar', 'score': 0.9998118, 'raw_content': None}, {'url': 'https://www.expedia.com/Things-To-Do-In-Karachi.d1809.Travel-Guide-Activities', 'title': 'Things to Do in Karachi in 2026 | Expedia', 'content': 'Discover the most popular places to visit in Karachi · Manora Beach · Clifton Beach · Hawks Bay · Mazar-e-Quaid · Frere Hall · French Beach · National Stadium · Bahria', 'score': 0.99970406, 'raw_content': None}, {'url': 'https://www.facebook.com/groups/191115458290452/posts/1674538939948089', 'title': 'What are some good places to visit in Karachi? - Facebook', 'content': 'Mubarak Village beach and Churna Island,two must visit places|TDF magnifiscience centre.. must see.', 'score': 0.9996458, 'raw_content': None}], 'response_time': 0.96, 'request_id': '04e19e4a-fcea-42f3-9efe-106d1712502f'}
# '1. **Famous Tourist Attractions in Karachi 2026 Places to Visit**\n   https://www.natureadventureclub.pk/best-tourist-attractions-in-karachi\n   # Best Things to do in Visit Karachi with Family 2026. Pakistan Tour Packages > Best Things to do in Visit Karachi with Family 2026. Tourist attractions in Karachi with Family. Port Grand is a perfect tourist attraction for a nighttime outing in Karachi. Featuring a charming promenade, a variety of...\n\n2. **10 Top Attractions in Karachi (2026) | Trip.com**\n   https://sg.trip.com/travel-guide/attraction/karachi-21342/tourist-attractions\n   1. Port Grand - Karachi · 2. Pakistan Air Force Museum · 3. Pakistan Maritime Museum · 4. Expo Centre Karachi · 5. Mazaar e Quaid Muhammad Ali Jinnah Mausoleum · 6.\n\n3. **List of tourist attractions in Karachi - Wikipedia**\n   https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Karachi\n   Monuments, mosques, temples and memorials · Hindu Gymkhana · Jehangir Kothari Parade · Grand Jamia Mosque · Masjid-e-Tooba · Mazare-e-Quaid Tomb · Shree Ratneshwar\n\n4. **Things to Do in Karachi in 2026 | Expedia**\n   https://www.expedia.com/Things-To-Do-In-Karachi.d1809.Travel-Guide-Activities\n   Discover the most popular places to visit in Karachi · Manora Beach · Clifton Beach · Hawks Bay · Mazar-e-Quaid · Frere Hall · French Beach · National Stadium · Bahria\n\n5. **What are some good places to visit in Karachi? - Facebook**\n   https://www.facebook.com/groups/191115458290452/posts/1674538939948089\n   Mubarak Village beach and Churna Island,two must visit places|TDF magnifiscience centre.. must see.'

# %%
  
import os
import requests
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("AVIATIONSTACK_API_KEY")


def search_flights(query):

    url = "http://api.aviationstack.com/v1/flights"

    params = {
        "access_key": API_KEY,
        "limit": 5
    }

    response = requests.get(url, params=params)

    data = response.json()

    flights = []

    if "data" in data:

        for flight in data["data"][:5]:

            airline = flight.get("airline", {}).get("name", "Unknown")

            departure = flight.get(
                "departure", {}
            ).get("airport", "Unknown")

            arrival = flight.get(
                "arrival", {}
            ).get("airport", "Unknown")

            status = flight.get("flight_status", "Unknown")

            flights.append(
                f"""
Airline: {airline}
Departure: {departure}
Arrival: {arrival}
Status: {status}
"""
            )

    return "\n".join(flights)
search_flights("The Flights from Karachi to London")
# Out:
# '\nAirline: Korean Air\nDeparture: Seoul (Incheon)\nArrival: Guangzhou Baiyun International\nStatus: scheduled\n\n\nAirline: Atlas Air\nDeparture: Seoul (Incheon)\nArrival: Chongqing Jiangbei International\nStatus: scheduled\n\n\nAirline: MIAT Mongolian Airlines\nDeparture: Seoul (Incheon)\nArrival: New Ulaanbaator International Airport\nStatus: scheduled\n\n\nAirline: Aeroflot\nDeparture: Vladivostok\nArrival: Harbin\nStatus: scheduled\n\n\nAirline: Aeroflot\nDeparture: Vladivostok\nArrival: Beijing Daxing International Airport\nStatus: scheduled\n'
